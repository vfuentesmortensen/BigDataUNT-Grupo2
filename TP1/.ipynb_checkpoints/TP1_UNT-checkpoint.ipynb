# %% [markdown]
# # Big Data (UNT) -  2024
#
# ## Trabajo Práctico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar debidamente documentado comentado (utilizando #) para que tanto los docentes como sus compañeros puedan comprender el código fácilmente.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Viernes 19 de septiembre a las 13:00 hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub llamado “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- en el canal de Slack #TP-entregas
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se corregirán sus tareas hasta no recibir el correo.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
# Importamos el paquete requests
import requests

buscar="despertador digital" #definimos una variable que contiene lo que queremos buscar
#usamos la API de ML siguiendo un formato general para obtener los ítems de una consulta de búsqueda
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20")) 

response = requests.request("GET", url) #definimos la variable response que usa el paquete requests para traer la información de la url
print(response) #verifica el pedido

response.text #obtenemos la información en formato texto
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"despertador digital","paging":{"total":723,"primary_results":723,"offset":0,"limit":50},"results":[{"id":"MLA1376282653","title":"Reloj Despertador Digital Cristal Liquido Alarma Temperatura Color Negro","condition":"new","thumbnail_id":"964428-MLU72628337582_112023","catalog_product_id":"MLA24304916","listing_type_id":"gold_special","sanitized_title":"reloj-despertador-digital-cristal-liquido-alarma-temperatura-color-negro","permalink":"https://www.mercadolibre.com.ar/reloj-despertador-digital-cristal-liquido-alarma-temperatura-color-negro/p/MLA24304916#wid=MLA1376282653&sid=unknown","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA3949","domain_id":"MLA-TABLE_AND_ALARM_CLOCKS","thumbnail":"http://http2.mlstatic.com/D_964428-MLU72628337582_112023-I.jpg","currency_id":"ARS","order_backend":1,"price":10199,"original_price":24500,"sale_price":{"price_id":"","amount":10199,"conditions":{"eligible":true,"context_restrictions":["channel_marketplace"],"start_time":"2024-07-01T03:00:00Z","end_time":"2024-09-29T03:00:00Z"},"currency_id":"ARS","exchange_rate":null,"payment_method_prices":[],"payment_method_type":"TMP","regular_amount":24500,"type":"promotion","metadata":{"campaign_id":"MLA55203","promotion_id":"OFFER-MLA1376282653-10135074472","promotion_type":"campaign"}},"available_quantity":250,"official_store_id":2839,"official_store_name":"LIBERCAM","use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":false,"logistic_type":"fulfillment","mode":"me2","tags":["fulfillment","MLA-CHG-threshold-nov-23","MLA-CHG-threshold-ene-24","self_service_out","self_service_available"],"benefits":null,"promise":null,"shipping_score":-1},"stop_time":"2043-07-03T04:00:00.000Z","seller":{"id":13647702,"nickname":"LIBERCAM"},"attributes":[{"id":"BRAND","name":"Marca","value_id":"5866747","value_name":"Libercam","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"5866747","name":"Libercam","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"COLOR","name":"Color","value_id":"52049","value_name":"Negro","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"52049","name":"Negro","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"GTIN","name":"Código universal de producto","value_id":null,"value_name":"7798375132640","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"7798375132640","struct":null,"source":385122562515662}],"source":8910742901282450,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":3045741222775799}],"source":3045741222775799,"value_type":"list"},{"id":"LENGTH","name":"Largo","value_id":"7857374","value_name":"14 cm","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":14,"unit":"cm"},"values":[{"id":"7857374","name":"14 cm","struct":{"number":14,"unit":"cm"},"source":1}],"source":1,"value_type":"number_unit"},{"id":"MAIN_COLOR","name":"Color principal","value_id":"2450295","value_name":"Negro","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2450295","name":"Negro","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"MODEL","name":"Modelo","value_id":"20582391","value_name":"RRD-00","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"20582391","name":"RRD-00","struct":null,"source":1}],"source":1,"value_type":"string"},{"id":"PACKAGE_LENGTH","name":"Largo del paquete","value_id":null,"value_name":"14.6 cm","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":14 ...

# %% [markdown]
# #### Ejercicio 2
# Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
# Guardamos primero los resultados en formato diccionario
data = response.json()
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'despertador digital',
#  'paging': {'total': 723, 'primary_results': 723, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA1376282653',
#    'title': 'Reloj Despertador Digital Cristal Liquido Alarma Temperatura Color Negro',
#    'condition': 'new',
#    'thumbnail_id': '964428-MLU72628337582_112023',
#    'catalog_product_id': 'MLA24304916',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-despertador-digital-cristal-liquido-alarma-temperatura-color-negro',
#    'permalink': 'https://www.mercadolibre.com.ar/reloj-despertador-digital-cristal-liquido-alarma-temperatura-color-negro/p/MLA24304916#wid=MLA1376282653&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_964428-MLU72628337582_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 10199,
#    'original_price': 24500,
#    'sale_price': {'price_id': '',
#     'amount': 10199,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-07-01T03:00:00Z',
#      'end_time': '2024-09-29T03:00:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 24500,
#     'type': 'promotion',
#     'metadata': {'campaign_id': 'MLA55203',
#      'promotion_id': 'OFFER-MLA1376282653-10135074472',
#      'promotion_type': 'campaign'}},
#    'available_quantity': 250,
#    'official_store_id': 2839,
#    'official_store_name': 'LIBERCAM',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'MLA-CHG-threshold-nov-23',
#      'MLA-CHG-threshold-ene-24',
#      'self_service_out',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-07-03T04:00:00.000Z',
#    'seller': {'id': 13647702, 'nickname': 'LIBERCAM'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5866747',
#      'value_name': 'Libercam',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5866747',
#        'name': 'Libercam',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798375132640',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798375132640',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 8910742901282450,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'source': 3045741222775799,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7857374',
#      'value_name': '14 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 14, 'unit': 'cm'},
#      'values': [{'id': '7857374',
#        'name': '14 cm',
#        'struct': {'number': 14, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450295',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450295',
#        'name': 'Negro',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20582391',
#      'value_name': 'RRD-00',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20582391',
#        'name': 'RRD-00',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '14.6 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 14.6, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '14.6 cm',
#        'struct': {'number': 14.6, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '160 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 160, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '160 g',
#        'struct': {'number': 160, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 2344.58,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'AXXP12742'},
#   {'id': 'MLA1791818690',
#    'title': 'Reloj Despertador Digital Led Temperatura Rbg Colores Color Blanco',
#    'condition': 'new',
#    'thumbnail_id': '805488-MLU73474158558_122023',
#    'catalog_product_id': 'MLA26268602',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-despertador-digital-led-temperatura-rbg-colores-color-blanco',
#    'permalink': 'https://www.mercadolibre.com.ar/reloj-despertador-digital-led-temperatura-rbg-colores-color-blanco/p/MLA26268602#wid=MLA1791818690&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_805488-MLU73474158558_122023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 5755.91,
#    'original_price': 18999,
#    'sale_price': {'price_id': '',
#     'amount': 5755.91,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-19T03:00:00Z',
#      'end_time': '2024-09-20T02:59:59Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 18999,
#     'type': 'promotion',
#     'metadata': {'promotion_type': 'deal_of_the_day',
#      'campaign_discount_percentage': 69.7,
#      'campaign_end_date': '2024-09-20T02:59:59Z',
#      'campaign_id': 'P-MLA14209152',
#      'discount_meli_amount': 123.09,
#      'funding_mode': 'coupon',
#      'order_item_price': 5879,
#      'promotion_id': 'OFFER-MLA1791818690-10177732683'}},
#    'available_quantity': 1,
#    'official_store_id': 2839,
#    'official_store_name': 'LIBERCAM',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out', 'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-05-25T04:00:00.000Z',
#    'seller': {'id': 13647702, 'nickname': 'LIBERCAM'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5866747',
#      'value_name': 'Libercam',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5866747',
#        'name': 'Libercam',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52055',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52055',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798375132541',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798375132541',
#        'struct': None,
#        'source': 3376461333454861}],
#      'source': 3376461333454861,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7818553',
#      'value_name': '8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 8, 'unit': 'cm'},
#      'values': [{'id': '7818553',
#        'name': '8 cm',
#        'struct': {'number': 8, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450308',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450308',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '23254611',
#      'value_name': 'REDE-05',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '23254611',
#        'name': 'REDE-05',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '8.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 8.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '8.8 cm',
#        'struct': {'number': 8.8, 'unit': 'cm'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '120 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 120, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '120 g',
#        'struct': {'number': 120, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 1323.19,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'UFAT22269'},
#   {'id': 'MLA1856299740',
#    'title': 'Reloj Despertador De Mesa Digital Usb Temperatura Y Alarma',
#    'condition': 'new',
#    'thumbnail_id': '672865-MLA77897792561_072024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-despertador-de-mesa-digital-usb-temperatura-y-alarma',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1856299740-reloj-despertador-de-mesa-digital-usb-temperatura-y-alarma-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_672865-MLA77897792561_072024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 16600,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 16600,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-07-18T04:00:00.000Z',
#    'seller': {'id': 235361526, 'nickname': 'IMPORTADORA RAIA'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '276243',
#      'value_name': 'Genérica',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '276243',
#        'name': 'Genérica',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': None,
#      'value_name': '5 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 5, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '5 cm',
#        'struct': {'number': 5, 'unit': 'cm'},
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'number_unit'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '14416329',
#      'value_name': 'Generic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '14416329',
#        'name': 'Generic',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'variations_data': {'183844338601': {'thumbnail': 'http://http2.mlstatic.com/D_672865-MLA77897792561_072024-O.jpg',
#      'ratio': '1.74',
#      'name': 'DISPLAY BLANCO',
#      'pictures_qty': 4,
#      'price': 16600,
#      'user_product_id': 'MLAU414720471',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]}},
#    'installments': {'quantity': 6,
#     'amount': 3816.06,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1856339016',
#    'title': 'Reloj Despertador De Mesa Digital Usb Alarma Y Temperatura',
#    'condition': 'new',
#    'thumbnail_id': '740668-MLA77678970492_072024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-despertador-de-mesa-digital-usb-alarma-y-temperatura',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1856339016-reloj-despertador-de-mesa-digital-usb-alarma-y-temperatura-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_740668-MLA77678970492_072024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 17030,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 17030,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-07-18T04:00:00.000Z',
#    'seller': {'id': 235361526, 'nickname': 'IMPORTADORA RAIA'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '276243',
#      'value_name': 'Genérica',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '276243',
#        'name': 'Genérica',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': None,
#      'value_name': '5 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 5, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '5 cm',
#        'struct': {'unit': 'cm', 'number': 5},
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'number_unit'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '14416329',
#      'value_name': 'Generic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '14416329',
#        'name': 'Generic',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'variations_data': {'181162152950': {'thumbnail': 'http://http2.mlstatic.com/D_740668-MLA77678970492_072024-O.jpg',
#      'ratio': '1.69',
#      'name': 'DISPLAY ROJO',
#      'pictures_qty': 4,
#      'price': 17030,
#      'inventory_id': 'UMSK86378',
#      'user_product_id': 'MLAU416488420',
#      'attributes': []}},
#    'installments': {'quantity': 6,
#     'amount': 3914.91,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1906197290',
#    'title': 'Reloj Despertador Alarma 8 Colores Led Cubo Luminoso Digital Color Blanco',
#    'condition': 'new',
#    'thumbnail_id': '919796-MLU74420080435_022024',
#    'catalog_product_id': 'MLA32251393',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-despertador-alarma-8-colores-led-cubo-luminoso-digital-color-blanco',
#    'permalink': 'https://www.mercadolibre.com.ar/reloj-despertador-alarma-8-colores-led-cubo-luminoso-digital-color-blanco/p/MLA32251393#wid=MLA1906197290&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_919796-MLU74420080435_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 5599,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 5599,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-09-05T04:00:00.000Z',
#    'seller': {'id': 1061357, 'nickname': 'SELLERALLARGENTINA'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '16116953',
#      'value_name': 'Digital',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '16116953',
#        'name': 'Digital',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52055',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52055',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7816577',
#      'value_name': '7 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 7, 'unit': 'cm'},
#      'values': [{'id': '7816577',
#        'name': '7 cm',
#        'struct': {'number': 7, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450308',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450308',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20936120',
#      'value_name': 'Digital Alarm Clock',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20936120',
#        'name': 'Digital Alarm Clock',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 1287.12,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1479310500',
#    'title': 'Despertador Digital Reloj Alarma Proyector Luz Despertador Color Negro',
#    'condition': 'new',
#    'thumbnail_id': '608981-MLU72627881012_112023',
#    'catalog_product_id': 'MLA26268608',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'despertador-digital-reloj-alarma-proyector-luz-despertador-color-negro',
#    'permalink': 'https://www.mercadolibre.com.ar/despertador-digital-reloj-alarma-proyector-luz-despertador-color-negro/p/MLA26268608#wid=MLA1479310500&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_608981-MLU72627881012_112023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 12136.48,
#    'original_price': 22999,
#    'sale_price': {'price_id': '',
#     'amount': 12136.48,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-19T03:00:00Z',
#      'end_time': '2024-09-20T02:59:59Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 22999,
#     'type': 'promotion',
#     'metadata': {'funding_mode': 'coupon',
#      'order_item_price': 12396,
#      'promotion_id': 'OFFER-MLA1479310500-10177734354',
#      'promotion_type': 'deal_of_the_day',
#      'campaign_discount_percentage': 47.23,
#      'campaign_end_date': '2024-09-20T02:59:59Z',
#      'campaign_id': 'P-MLA14209152',
#      'discount_meli_amount': 259.52}},
#    'available_quantity': 1,
#    'official_store_id': 2839,
#    'official_store_name': 'LIBERCAM',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment', 'self_service_out', 'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-08-17T04:00:00.000Z',
#    'seller': {'id': 13647702, 'nickname': 'LIBERCAM'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5866747',
#      'value_name': 'Libercam',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5866747',
#        'name': 'Libercam',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52049',
#      'value_name': 'Negro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52049', 'name': 'Negro', 'struct': None, 'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798383031515',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798383031515',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7818795',
#      'value_name': '11 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 11, 'unit': 'cm'},
#      'values': [{'id': '7818795',
#        'name': '11 cm',
#        'struct': {'number': 11, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450308',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450308',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '20582393',
#      'value_name': 'RPT-300',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '20582393',
#        'name': 'RPT-300',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '15.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 15.8, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '15.8 cm',
#        'struct': {'number': 15.8, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '220 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 220, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '220 g',
#        'struct': {'number': 220, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 2789.97,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'OMQP77202'},
#   {'id': 'MLA1401746057',
#    'title': 'Reloj Despertador Alarma Proyector Libercam Estrellas Con Musica',
#    'condition': 'new',
#    'thumbnail_id': '836064-MLU70684056581_072023',
#    'catalog_product_id': 'MLA29543567',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-despertador-alarma-proyector-libercam-estrellas-con-musica',
#    'permalink': 'https://www.mercadolibre.com.ar/reloj-despertador-alarma-proyector-libercam-estrellas-con-musica/p/MLA29543567#wid=MLA1401746057&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_836064-MLU70684056581_072023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 9488.15,
#    'original_price': 22999,
#    'sale_price': {'price_id': '',
#     'amount': 9488.15,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-19T03:00:00Z',
#      'end_time': '2024-09-20T02:59:59Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 22999,
#     'type': 'promotion',
#     'metadata': {'funding_mode': 'coupon',
#      'order_item_price': 9691,
#      'promotion_id': 'OFFER-MLA1401746057-10177732866',
#      'promotion_type': 'deal_of_the_day',
#      'campaign_discount_percentage': 58.75,
#      'campaign_end_date': '2024-09-20T02:59:59Z',
#      'campaign_id': 'P-MLA14209152',
#      'discount_meli_amount': 202.85}},
#    'available_quantity': 50,
#    'official_store_id': 2839,
#    'official_store_name': 'LIBERCAM',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'MLA-CHG-threshold-nov-23',
#      'MLA-CHG-threshold-ene-24',
#      'self_service_out',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-01-04T04:00:00.000Z',
#    'seller': {'id': 13647702, 'nickname': 'LIBERCAM'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5866747',
#      'value_name': 'Libercam',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5866747',
#        'name': 'Libercam',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52055',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52055',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '7798375132619',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '7798375132619',
#        'struct': None,
#        'source': 385122562515662}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '7816454',
#      'value_name': '10 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 10, 'unit': 'cm'},
#      'values': [{'id': '7816454',
#        'name': '10 cm',
#        'struct': {'number': 10, 'unit': 'cm'},
#        'source': 4060709329251625}],
#      'source': 4060709329251625,
#      'value_type': 'number_unit'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '21596507',
#      'value_name': 'RDVE-120',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '21596507',
#        'name': 'RDVE-120',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '11.2 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 11.2, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '11.2 cm',
#        'struct': {'number': 11.2, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '160 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 160, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '160 g',
#        'struct': {'number': 160, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 2181.17,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'CFDI75427'},
#   {'id': 'MLA1599531328',
#    'title': 'Reloj Digital Alarma Despertador Proyector Luz Led Holograma',
#    'condition': 'new',
#    'thumbnail_id': '994317-MLA73431489543_122023',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-digital-alarma-despertador-proyector-luz-led-holograma',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1599531328-reloj-digital-alarma-despertador-proyector-luz-led-holograma-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_994317-MLA73431489543_122023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 34999,
#    'original_price': 55591,
#    'sale_price': {'price_id': '',
#     'amount': 34999,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-12T03:00:00Z',
#      'end_time': '2024-09-20T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 55591,
#     'type': 'promotion',
#     'metadata': {'promotion_id': 'OFFER-MLA1599531328-10177553073',
#      'promotion_type': 'marketplace_campaign',
#      'variation': '51566',
#      'campaign_end_date': '2024-09-20T02:59:00Z',
#      'campaign_id': 'P-MLA14213020',
#      'campaign_discount_percentage': 37.04,
#      'experiment_id': 'cm_med_uplift_P-MLA14213020',
#      'funding_mode': 'coupon',
#      'discount_meli_amount': 1225,
#      'order_item_price': 36224}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'fulfillment',
#     'mode': 'me2',
#     'tags': ['fulfillment',
#      'self_service_out',
#      'mandatory_free_shipping',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-12-09T04:00:00.000Z',
#    'seller': {'id': 259507860, 'nickname': 'NORCELHOME'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5512424',
#      'value_name': 'Norcel',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5512424',
#        'name': 'Norcel',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': None,
#      'value_name': '9 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 9, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '9 cm',
#        'struct': {'number': 9, 'unit': 'cm'},
#        'source': 6536000100455122}],
#      'source': 6536000100455122,
#      'value_type': 'number_unit'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'EN8831',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'EN8831',
#        'struct': None,
#        'source': 6536000100455122}],
#      'source': 6536000100455122,
#      'value_type': 'string'}],
#    'variations_data': {'179447327618': {'thumbnail': 'http://http2.mlstatic.com/D_994317-MLA73431489543_122023-O.jpg',
#      'ratio': '1.45',
#      'name': 'Negro Con Luz Blanca',
#      'pictures_qty': 5,
#      'price': 56308,
#      'inventory_id': 'ZJAG47074',
#      'user_product_id': 'MLAU129631902',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': None}]},
#     '179447327620': {'thumbnail': 'http://http2.mlstatic.com/D_667350-MLA73431696611_122023-O.jpg',
#      'ratio': '1.24',
#      'name': 'Negro Con Luz Roja',
#      'pictures_qty': 5,
#      'price': 56308,
#      'inventory_id': 'BIIN47884',
#      'user_product_id': 'MLAU129633110',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': None}]},
#     '179447327622': {'thumbnail': 'http://http2.mlstatic.com/D_667350-MLA73431696611_122023-O.jpg',
#      'ratio': '1.24',
#      'name': 'Negro Con Luz Azul',
#      'pictures_qty': 10,
#      'price': 56308,
#      'inventory_id': 'OXGS47821',
#      'user_product_id': 'MLAU128867873',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': None}]}},
#    'installments': {'quantity': 6,
#     'amount': 8045.69,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1417678463',
#    'title': 'Reloj Digital Cubo Luces Led Alarma Despertador Temperatura Color Blanco',
#    'condition': 'new',
#    'thumbnail_id': '830706-MLU73234595894_122023',
#    'catalog_product_id': 'MLA26042690',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'reloj-digital-cubo-luces-led-alarma-despertador-temperatura-color-blanco',
#    'permalink': 'https://www.mercadolibre.com.ar/reloj-digital-cubo-luces-led-alarma-despertador-temperatura-color-blanco/p/MLA26042690#wid=MLA1417678463&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_830706-MLU73234595894_122023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 9,
#    'price': 5550,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 5550,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-03-20T04:00:00.000Z',
#    'seller': {'id': 96642992, 'nickname': 'LACUEVADELTAPICERO'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '8900905',
#      'value_name': 'Suono',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '8900905',
#        'name': 'Suono',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'COLOR',
#      'name': 'Color',
#      'value_id': '52055',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '52055',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '701575361823',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '701575361823',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': '14754342',
#      'value_name': '7.8 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 7.8, 'unit': 'cm'},
#      'values': [{'id': '14754342',
#        'name': '7.8 cm',
#        'struct': {'number': 7.8, 'unit': 'cm'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'},
#     {'id': 'MAIN_COLOR',
#      'name': 'Color principal',
#      'value_id': '2450308',
#      'value_name': 'Blanco',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2450308',
#        'name': 'Blanco',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '22943763',
#      'value_name': 'CUBO 8212 ARG',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '22943763',
#        'name': 'CUBO 8212 ARG',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 1275.85,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1730797752',
#    'title': 'Reloj De Mesa  Despertador  Digital Norcel Wake Up Light Alarm Clock Color Blanco  100v/240v',
#    'condition': 'new',
#    'thumbnail_id': '707918-MLA73927369655_012024',
#    'catalog_product_id': 'MLA29617880',
#    'listing_type_id': 'gold_pro',
#    'sanitized_title': 'reloj-de-mesa-despertador-digital-norcel-wake-up-light-alarm-clock-color-blanco-100v240v',
#    'permalink': 'https://www.mercadolibre.com.ar/reloj-de-mesa-despertador-digital-norcel-wake-up-light-alarm-clock-color-blanco-100v240v/p/MLA29617880#wid=MLA1730797752&sid=unknown',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA3949',
#    'domain_id': 'MLA-TABLE_AND_ALARM_CLOCKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_707918-MLA73927369655_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 10,
#    'price': 52046,
#    'original_price': 88651,
#    'sale_price': {'price_id': '',
#     'amount': 52046,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-12T03:00:00Z',
#      'end_time': '2024-09-20T02:59:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 88651,
#     'type': 'promotion',
#     'metadata': {'experiment_id': 'cm_med_uplift_P-MLA14213020',
#      'funding_mode': 'coupon',
#      'promotion_id': 'OFFER-MLA1730797752-10176120278',
#      'campaign_end_date': '2024-09-20T02:59:00Z',
#      'discount_meli_amount': 2000,
#      'order_item_price': 54046,
#      'promotion_type': 'marketplace_campaign',
#      'variation': '51566',
#      'campaign_discount_percentage': 41.29,
#      'campaign_id': 'P-MLA14213020'}},
#    'available_quantity': 50,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-03-31T04:00:00.000Z',
#    'seller': {'id': 259507860, 'nickname': 'NORCELHOME'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5512424',
#      'value_name': 'Norcel',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '5512424',
#        'name': 'Norcel',
# ...
#      'value_name': 'L8D11713-CH',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '23144441',
#        'name': 'L8D11713-CH',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '7.2 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 7.2, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '7.2 cm',
#        'struct': {'unit': 'cm', 'number': 7.2},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': None,
#      'value_name': '200 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 200, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '200 g',
#        'struct': {'number': 200, 'unit': 'g'},
#        'source': 4333789534002961}],
#      'source': 4333789534002961,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 3965.22,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': 'EFYK96175'}],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA3949',
#      'name': 'Despertadores y de Mesa',
#      'path_from_root': [{'id': 'MLA3937', 'name': 'Joyas y Relojes'},
#       {'id': 'MLA431677', 'name': 'Relojes'},
#       {'id': 'MLA3949', 'name': 'Despertadores y de Mesa'}]}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 74},
#     {'id': '2839', 'name': 'LIBERCAM', 'results': 7},
#     {'id': '3209', 'name': 'Bidcom', 'results': 10},
#     {'id': '945', 'name': 'Gadnic', 'results': 10},
#     {'id': '95088', 'name': 'RUMISH', 'results': 2},
#     {'id': '86302', 'name': 'Franmark', 'results': 2},
#     {'id': '87694', 'name': 'PLANETA ZENOK', 'results': 2},
#     {'id': '2408', 'name': 'Jugueteria Cachavacha', 'results': 1},
#     {'id': '52373', 'name': 'Gamaleds', 'results': 1}]},
#   {'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 562},
#     {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste', 'results': 48},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 31},
#     {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 26},
#     {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte', 'results': 20},
#     {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 13},
#     {'id': 'TUxBUFpPTmFpbnRl', 'name': 'Buenos Aires Interior', 'results': 3},
#     {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 2},
#     {'id': 'TUxBUENPU2ExMmFkMw',
#      'name': 'Bs.As. Costa Atlántica',
#      'results': 2},
#     {'id': 'TUxBUExBWmE1OWMy', 'name': 'La Pampa', 'results': 2},
#     {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 1}]},
#   {'id': 'discount',
#    'name': 'Descuentos',
#    'type': 'number',
#    'values': [{'id': '5-100', 'name': 'Desde 5% OFF', 'results': 217},
#     {'id': '10-100', 'name': 'Desde 10% OFF', 'results': 152},
#     {'id': '15-100', 'name': 'Desde 15% OFF', 'results': 67},
#     {'id': '20-100', 'name': 'Desde 20% OFF', 'results': 54},
#     {'id': '25-100', 'name': 'Desde 25% OFF', 'results': 26},
#     {'id': '30-100', 'name': 'Desde 30% OFF', 'results': 17},
#     {'id': '40-100', 'name': 'Desde 40% OFF', 'results': 5},
#     {'id': '50-100', 'name': 'Desde 50% OFF', 'results': 1}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-10000.0', 'name': 'Hasta $ 10.000', 'results': 143},
#     {'id': '10000.0-20000.0', 'name': '$10.000 a $20.000', 'results': 267},
#     {'id': '20000.0-*', 'name': 'Más de $20.000', 'results': 313}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con MercadoPago', 'results': 723}]},
#   {'id': 'installments',
#    'name': 'Financiación',
#    'type': 'text',
#    'values': [{'id': 'yes', 'name': 'En cuotas', 'results': 718},
#     {'id': 'no_interest', 'name': 'Sin interés', 'results': 136}]},
#   {'id': 'shipping',
#    'name': 'Envío',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envíos',
#      'results': 723},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 36}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 541}]},
#   {'id': 'since',
#    'name': 'Filtro por fecha de comienzo',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Publicados hoy', 'results': 1}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicaciones con video',
#    'type': 'boolean',
#    'values': [{'id': 'yes',
#      'name': 'Publicaciones con video',
#      'results': 35}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 723}]},
#   {'id': 'all_payment_methods_discount',
#    'name': 'Descuentos para todos los medios de pago',
#    'type': 'number',
#    'values': [{'id': '5-100', 'name': 'Desde 5% OFF', 'results': 79},
#     {'id': '10-100', 'name': 'Desde 10% OFF', 'results': 73},
#     {'id': '15-100', 'name': 'Desde 15% OFF', 'results': 10},
#     {'id': '25-100', 'name': 'Desde 25% OFF', 'results': 4},
#     {'id': '30-100', 'name': 'Desde 30% OFF', 'results': 3}]},
#   {'id': 'price_campaign_id',
#    'name': 'Campaña',
#    'type': 'number',
#    'values': [{'id': 'MLA55203', 'name': 'MLA55203', 'results': 7},
#     {'id': 'P-MLA14213220', 'name': 'P-MLA14213220', 'results': 7},
#     {'id': 'P-MLA14213020', 'name': 'P-MLA14213020', 'results': 6},
#     {'id': 'P-MLA14209152', 'name': 'P-MLA14209152', 'results': 5},
#     {'id': 'P-MLA14209002', 'name': 'P-MLA14209002', 'results': 4},
#     {'id': 'MLA55348', 'name': 'MLA55348', 'results': 3},
#     {'id': 'MLA55381', 'name': 'MLA55381', 'results': 3},
#     {'id': 'MLA55016', 'name': 'MLA55016', 'results': 1},
#     {'id': 'MLA55368', 'name': 'MLA55368', 'results': 1},
#     {'id': 'MLA55009', 'name': 'MLA55009', 'results': 1},
#     {'id': 'MLA55338', 'name': 'MLA55338', 'results': 1}]},
#   {'id': 'promotion_type',
#    'name': 'Tipo de promoción',
#    'type': 'text',
#    'values': [{'id': 'deal_of_the_day',
#      'name': 'Oferta del día',
#      'results': 6}]},
#   {'id': 'shipping_cost',
#    'name': 'Costo de envío',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 179}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '276243', 'name': 'Genérica', 'results': 111},
#     {'id': '2232566', 'name': 'Eurotime', 'results': 60},
#     {'id': '2153571', 'name': 'Tapimovil', 'results': 50},
#     {'id': '410974', 'name': 'Gadnic', 'results': 23},
#     {'id': '1133', 'name': 'Casio', 'results': 23},
#     {'id': '8900905', 'name': 'Suono', 'results': 17},
#     {'id': '4190035', 'name': 'MAS Accesorios', 'results': 12},
#     {'id': '2242631', 'name': 'Europa', 'results': 11},
#     {'id': '5023971', 'name': 'MoodiCare', 'results': 10},
#     {'id': '415126', 'name': 'Daza', 'results': 9},
#     {'id': '6630631', 'name': 'Master Sale', 'results': 8},
#     {'id': '5866747', 'name': 'Libercam', 'results': 8},
#     {'id': '34882645', 'name': 'Dioggisa', 'results': 8},
#     {'id': '2786070', 'name': 'Dakot', 'results': 8},
#     {'id': '24870961', 'name': 'Wooden Clock', 'results': 8},
#     {'id': '5618436', 'name': 'Gorsh', 'results': 7},
#     {'id': '2869698', 'name': 'Shoot', 'results': 7},
#     {'id': '28517', 'name': 'Crown Mustang', 'results': 7},
#     {'id': '6780447', 'name': 'Etheos', 'results': 6},
#     {'id': '2426343', 'name': 'Dinax', 'results': 6},
#     {'id': '22050052', 'name': 'Mania-Electronic', 'results': 6},
#     {'id': '18842596', 'name': 'La Huella IMport', 'results': 6},
#     {'id': '5512424', 'name': 'Norcel', 'results': 5},
#     {'id': '14333592', 'name': 'Art Home', 'results': 5},
#     {'id': '97698', 'name': 'HB', 'results': 4},
#     {'id': '36092180', 'name': 'Mijalshop', 'results': 4},
#     {'id': '269908', 'name': 'Novik Neo', 'results': 4},
#     {'id': '10314378', 'name': 'Ocean Gadgets', 'results': 4},
#     {'id': '593', 'name': 'Ken Brown', 'results': 3},
#     {'id': '4414255', 'name': 'Yaay!', 'results': 3},
#     {'id': '4055800', 'name': 'Miniso', 'results': 3},
#     {'id': '2656407', 'name': 'Emax', 'results': 3},
#     {'id': '25735317', 'name': 'Megasale', 'results': 3},
#     {'id': '20034', 'name': 'Luft', 'results': 3},
#     {'id': '19439119', 'name': 'Price Mania', 'results': 3},
#     {'id': '17235', 'name': 'Divoom', 'results': 3},
#     {'id': '16885108', 'name': 'Wireless Charger', 'results': 3},
#     {'id': '15919994', 'name': 'Cantares Productos', 'results': 3},
#     {'id': '12901933', 'name': 'Madison', 'results': 3},
#     {'id': '9232788', 'name': 'Dala Games', 'results': 2},
#     {'id': '8022662', 'name': 'Buenos Aires LED', 'results': 2},
#     {'id': '7494', 'name': 'Lenovo', 'results': 2},
#     {'id': '5630939', 'name': 'Nako', 'results': 2},
#     {'id': '5610252', 'name': 'Good & Good', 'results': 2},
#     {'id': '5244747', 'name': 'FanJu', 'results': 2},
#     {'id': '2929513', 'name': 'Thumbs Up', 'results': 2},
#     {'id': '28125413', 'name': 'Miyee', 'results': 2},
#     {'id': '2617936', 'name': 'Keenly', 'results': 2},
#     {'id': '25585939', 'name': 'We Glam', 'results': 2},
#     {'id': '2522687', 'name': 'DG', 'results': 2},
#     {'id': '2088733', 'name': 'Univex', 'results': 2},
#     {'id': '20634504', 'name': 'Gaosiio', 'results': 2},
#     {'id': '20568746', 'name': 'Digital Clock', 'results': 2},
#     {'id': '15886508', 'name': 'Coper Light', 'results': 2},
#     {'id': '15877045', 'name': 'Will', 'results': 2},
#     {'id': '13736368', 'name': 'Cositas y Cositas', 'results': 2},
#     {'id': '13250952', 'name': 'WIL', 'results': 2},
#     {'id': '12913880', 'name': 'Xinjia', 'results': 2},
#     {'id': '1249457', 'name': 'New Mar', 'results': 2},
#     {'id': '10886', 'name': 'Seiko', 'results': 2},
#     {'id': '1002557', 'name': 'OSR', 'results': 2},
#     {'id': '98571', 'name': 'Sansei', 'results': 1},
#     {'id': '5656719', 'name': 'Paw Patrol', 'results': 1},
#     {'id': '5647937', 'name': 'Chaowei', 'results': 1},
#     {'id': '563', 'name': 'Premium', 'results': 1},
#     {'id': '5581463', 'name': 'MS', 'results': 1},
#     {'id': '5411791', 'name': 'Wake Up', 'results': 1},
#     {'id': '5161570', 'name': 'Quartz', 'results': 1},
#     {'id': '4892260', 'name': 'Hytoshy', 'results': 1},
#     {'id': '465450', 'name': 'GB', 'results': 1},
#     {'id': '4576063', 'name': 'Flying', 'results': 1},
#     {'id': '444660', 'name': 'Brookstone', 'results': 1},
#     {'id': '4208', 'name': 'Daewoo', 'results': 1},
#     {'id': '416273', 'name': 'Lemon', 'results': 1},
#     {'id': '416075', 'name': 'Oryx', 'results': 1},
#     {'id': '3782994', 'name': 'Aloha', 'results': 1},
#     {'id': '37481044', 'name': 'Dtop', 'results': 1},
#     {'id': '37333', 'name': 'Oregon Scientific', 'results': 1},
#     {'id': '36131840', 'name': 'Pplee', 'results': 1},
#     {'id': '3435', 'name': 'Crown', 'results': 1},
#     {'id': '31868327', 'name': 'Mesqool', 'results': 1},
#     {'id': '3047794', 'name': 'Lexon', 'results': 1},
#     {'id': '3046835', 'name': 'Morph', 'results': 1},
#     {'id': '28301865', 'name': 'Vivilumens', 'results': 1},
#     {'id': '2804265', 'name': 'SM', 'results': 1},
#     {'id': '26191696', 'name': 'YYD Small', 'results': 1},
#     {'id': '26005', 'name': 'Sankyo', 'results': 1},
#     {'id': '25731063', 'name': 'Dreamsky', 'results': 1},
#     {'id': '25651827', 'name': 'Snooze', 'results': 1},
#     {'id': '2480847', 'name': 'Tomy', 'results': 1},
#     {'id': '24319183', 'name': 'Hatch', 'results': 1},
#     {'id': '23477866', 'name': 'Atena', 'results': 1},
#     {'id': '2132509', 'name': 'Ornet', 'results': 1},
#     {'id': '20689481', 'name': 'AVL', 'results': 1},
#     {'id': '17648705', 'name': 'Melcolors', 'results': 1},
#     {'id': '17228', 'name': 'Fuego', 'results': 1},
#     {'id': '16941676', 'name': 'Gxtronics', 'results': 1},
#     {'id': '16599', 'name': 'Aiwa', 'results': 1},
#     {'id': '16269', 'name': 'Kenko', 'results': 1},
#     {'id': '15896547', 'name': 'Yydsmart', 'results': 1},
#     {'id': '14032623', 'name': 'Star Vision', 'results': 1},
#     {'id': '13746877', 'name': 'Rumish', 'results': 1},
#     {'id': '13651735', 'name': 'Belmotec', 'results': 1},
#     {'id': '1249447', 'name': 'Lego', 'results': 1},
#     {'id': '11867342', 'name': 'Angelus', 'results': 1},
#     {'id': '115716', 'name': 'Playskool', 'results': 1},
#     {'id': '1149864', 'name': 'Paddle Watch', 'results': 1},
#     {'id': '108568', 'name': 'Crystal', 'results': 1},
#     {'id': '1001181', 'name': 'Tressa', 'results': 1}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 687},
#     {'id': '2230581', 'name': 'Usado', 'results': 35}]},
#   {'id': 'MAIN_COLOR',
#    'name': 'Color principal',
#    'type': 'list',
#    'values': [{'id': '2450308', 'name': 'Blanco', 'results': 210},
#     {'id': '2450295', 'name': 'Negro', 'results': 99},
#     {'id': '2450307', 'name': 'Rojo', 'results': 18},
#     {'id': '2450294', 'name': 'Gris', 'results': 16},
#     {'id': '2450293', 'name': 'Azul', 'results': 15},
#     {'id': '2450278', 'name': 'Celeste', 'results': 11},
#     {'id': '2450312', 'name': 'Rosa', 'results': 10},
#     {'id': '2450303', 'name': 'Plateado', 'results': 10},
#     {'id': '2450314', 'name': 'Verde', 'results': 7},
#     {'id': '2450291', 'name': 'Marrón', 'results': 5},
#     {'id': '2450311', 'name': 'Violeta', 'results': 3},
#     {'id': '2450327', 'name': 'Naranja', 'results': 2},
#     {'id': '2450296', 'name': 'Amarillo', 'results': 2},
#     {'id': '2450289', 'name': 'Dorado', 'results': 1}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLA24304916', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26268602', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA32251393', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26268608', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29543567', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26042690', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29617880', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24574342', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26268604', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA35573272', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA34150707', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA37088872', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA27628284', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24728552', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26834394', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA24304918', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26042689', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26166412', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25193606', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26903991', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA38506688', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29731824', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29730426', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA29597700', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA25265120', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA26268605', 'score': 1, 'status': 'shown'}]},
#  'user_context': None}

# %%
# Construcción del data frame

import pandas as pd #importamos el paquete de pandas 

items = data['results']
precios = [item['price'] for item in items]
 
precios_df= pd.DataFrame(precios, columns=['Precio']) #creamos un DataFrame con los precios
#print(precios_df)

# Calculo del precio promedio, mínimo y máximo

print('El precio promedio es', precios_df['Precio'].mean())
print('El precio mínimo es', precios_df['Precio'].min())
print('El precio máximo es', precios_df['Precio'].max())
# Out:
# El precio promedio es 19484.900800000003
# El precio mínimo es 5199.0
# El precio máximo es 110000.0

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
# Creamos el histograma con matplotlib

# !pip install matplotlib
# import matplotlib.pyplot as plt  #instalamos matplotlib

precios_df['Precio'].plot.hist(bins=20, edgecolor='black', title='Histograma de Precios de Despertadores Digitales en ML')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# Identificamos que hay un outlier que se corresponde con el precio maximo de $110.000,00 que calculamos en el punto anterior.

# %% [markdown]
# #### Ejercicio 4
# Realicen alguna consulta adicional utilizando la API de Mercado Libre (debe ser alguna consulta que no se haya visto en clase. Por ejemplo, obtener los ítems de un vendedor en particular, obtener los productos de una categoría u otros). Analicen los resultados y comenten uno o dos que les parezcan interesantes (por ejemplo, precios promedio de los productos de un vendedor, diferencia entre el precio original y actual, si acepta mercado pago para la compra de productos, etc.)

# %%
# Resolver acá
seller="philips" #definimos una variable que contiene lo que queremos buscar
#usamos la API de ML siguiendo un formato general para obtener los ítems de una consulta de búsqueda
#url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20")) 
url = "https://api.mercadolibre.com/sites/{}/search?nickname={}".format("MLA", seller) 

response = requests.request("GET", url) #definimos la variable response que usa el paquete requests para traer la información de la url
print(response) #verifica el pedido

response.text #obtenemos la información en formato texto
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","paging":{"total":0,"primary_results":0,"offset":0,"limit":50},"results":[],"sort":{"id":"relevance","name":"Más relevantes"},"available_sorts":[{"id":"price_asc","name":"Menor precio"},{"id":"price_desc","name":"Mayor precio"}],"filters":[],"available_filters":[],"pdp_tracking":{"group":false,"product_info":[]},"user_context":null}'

# %%
# guardamos los resultados en formato diccionario
data = response.json()
data
    
# Obtener los resultados de los ítems
items = data.get('results',[])

#Mostrar los primeros 5 ítems como ejemplo
for item in items[:5]:
    print(f"Nombre: {item['title']}")
    print(f"Precio: {item['price']}")
    print(f"Link: {item['permalink']}")
    print('-' * 40)
else:
    print(f"Error en la solicitud: {response.status_code}")
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'paging': {'total': 0, 'primary_results': 0, 'offset': 0, 'limit': 50},
#  'results': [],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [],
#  'available_filters': [],
#  'pdp_tracking': {'group': False, 'product_info': []},
#  'user_context': None}

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 5
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/), utilicen herramientas de web scraping para obtener los links de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
# Resolver acá
